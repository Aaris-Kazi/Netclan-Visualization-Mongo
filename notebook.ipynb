# %%
import pandas as pd

# %%
df = pd.read_json('jsondata.json')

# %%
df
# Out:
#     end_year intensity              sector        topic  \
# 0                    6              Energy          gas
# 1                    6              Energy          oil
# 2                    6              Energy  consumption
# 3                    6         Environment          oil
# 4                    6                           market
# ..       ...       ...                 ...          ...
# 995                  2  Financial services          oil
# 996     2016                 Manufacturing       growth
# 997                 16                           growth
# 998     2016         3              Retail       export
# 999                  2
#
#                                                insight  \
# 0                                Annual Energy Outlook
# 1                                Annual Energy Outlook
# 2                                Annual Energy Outlook
# 3    WRI Partnership Aims to Foster Supply Chain Tr...
# ...

# %%
import matplotlib.pyplot as plt

# %%
x =df.groupby('intensity')['topic'].agg('sum')

# %%
x
# Out:
# intensity
# 1                                                   oil
# 2     politicsgasriskoilgaseconomydemandoilgaseconom...
# 3     oilenergygovernmentenergygrowthcoalgrowthcloth...
# 4     productionbiofuelenergyoiloilgasunemploymentde...
# 6     gasoilconsumptionoilmarketoilwarexportoiloiloi...
# 8     oilpolicygrowtheconomicoileconomyoiloiloiloilg...
# 9     batteryoiloilenergycapitaloiltransporticegasoi...
# 10                                  vehicleoiloilenergy
# 12    oiloiloiloiloiloilgasgrowtheconomic growthexpo...
# 14                                                  oil
# 15                                                  oil
# 16    oilgdpoileconomymarketoilgrowthgrowthoiloiloil...
# 18                                            oiloiloil
# 20    oilgasoiloiloiloilgrowthoiloilgrowthoiloiloilo...
# 24               strategyoiloilexportmarketoiloiloiloil
# 30                                             gasoline
# 32                                        exportdebtgas
# ...

# %%
x.plot(kind = 'bar')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-7d7afb275178> in <module>
# ----> 1 x.plot(kind = 'bar')
#
# c:\Users\aaris\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\plotting\_core.py in __call__(self, *args, **kwargs)
#     970                     data.columns = label_name
#     971
# --> 972         return plot_backend.plot(data, kind=kind, **kwargs)
#     973
#     974     __call__.__doc__ = __doc__
#
# c:\Users\aaris\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\plotting\_matplotlib\__init__.py in plot(data, kind, **kwargs)
#      69             kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71     plot_obj.generate()
#      72     plot_obj.draw()
#      73     return plot_obj.result
#
# ...

# %%
for i in x:
    print(i)
# Out:
# (1, 501    oil
# Name: topic, dtype: object)
# (2, 162    politics
# 356         gas
# 379        risk
# 380         oil
# 387         gas
#          ...
# 991         gas
# 992
# 993         oil
# 995         oil
# 999
# Name: topic, Length: 65, dtype: object)
# (3, 309           oil
# 357        energy
# 358    government
# 361        energy
# 381        growth
#           ...
# 980           war
# 982      fracking
# 983
# 994           oil
# 998        export
# Name: topic, Length: 80, dtype: object)
# (4, 10     production
# 18        biofuel
# 36         energy
# 63            oil
# 67            oil
#           ...
# 964         money
# 965           oil
# 970
# 981           gas
# 989           oil
# Name: topic, Length: 98, dtype: object)
# (6, 0              gas
# 1              oil
# 2      consumption
# 3              oil
# 4           market
#           ...
# 960            oil
# 971         energy
# 973            oil
# 974       security
# 979         energy
# ...
